# %%
# importing dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading dataset
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# checking the number of rows and columns 
data.shape
# Out:
# (284807, 31)

# %%
# getting the dataset stats
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# checking if there are null values 
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# checking the number of each value in the target column
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# atributing variables for each item of target colums
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
# getting stats abour the ligit values
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# getting stats abour the fraud values

fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# grouping the class items to understand the stats and differences between the target values
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# chosing among legit sample the same number of rows as fraud sample
legit_sample = legit.sample(n=492)

# %%
# concatenate the legit sample and the fraud sameple
data_new = pd.concat([legit_sample, fraud], axis=0)
data_new.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 109504   71410.0 -1.187181  1.047231 -0.438273 -0.312530  2.377034  3.519813
# 148557   90043.0  2.045375 -0.030927 -2.812511 -0.375668  2.684930  3.189283
# 200058  133262.0  0.302161  0.009053  0.032235 -1.988914  0.162366 -0.504161
# 92569    63993.0 -3.150128  3.730753 -1.831957  0.146299 -0.636663 -0.931582
# 94598    64947.0 -6.373391  3.301783  1.727041 -1.588447  0.185362  0.225313
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 109504  0.089788  0.977289 -0.560268  ... -0.047391 -0.082154 -0.192479
# 148557 -0.511089  0.704131  1.644990  ... -0.503497 -1.182600  0.376215
# 200058  0.500912 -0.106563 -1.522928  ...  0.082722  0.034283  0.171083
# 92569   0.047542  0.907407  1.212299  ... -0.099198  0.356052  0.227021
# 94598   2.958156 -3.419036  7.937988  ... -1.612952  0.386673 -0.365157
#
# ...

# %%
# checking if now we have the same number of fraud and legit items
data_new['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
# grouping the class items to understand the stats and differences between the target values

data_new.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95294.713415 -0.211804 -0.008139  0.070330 -0.062037  0.038865
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.041457  0.043818 -0.034105  0.051555  ...  0.011113 -0.010127
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.048453  0.014204  0.020141 -0.008931 -0.020975  0.024055 -0.013018
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      100.203293
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# splitting the dataset in feature and target
X = data_new.drop(['Class'], axis=1)
y = data_new['Class']

# %%
# splitting the dataset in train and test samples
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2, test_size=0.2, stratify=y)

# %%
# importing the model
from sklearn.linear_model import LogisticRegression

# %%
# training and predicting the train sample
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
pred = model.predict(X_train)

# %%
# importing the metrics
from sklearn.metrics import classification_report, roc_auc_score, roc_curve

# %%
classification = classification_report(y_train, pred)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       393
#            1       0.98      0.93      0.95       394
#
#     accuracy                           0.95       787
#    macro avg       0.95      0.95      0.95       787
# weighted avg       0.95      0.95      0.95       787

# %%
#  predicting the test sample
pred_test = model.predict(X_test)
classification = classification_report(y_test, pred_test)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        99
#            1       0.98      0.90      0.94        98
#
#     accuracy                           0.94       197
#    macro avg       0.94      0.94      0.94       197
# weighted avg       0.94      0.94      0.94       197

# %%
roc = roc_auc_score(y_test, pred_test)
print(f'The ROC-AUC score is {roc:.2f}')
# Out:
# The ROC-AUC score is 0.94

# %%
tpr, tnr, limit = roc_curve(y_test, pred_test)

# %%
#plotting ROC Curve graph
plt.subplots(1, figsize = (5,5))
plt.title('ROC Curve')
plt.plot(tpr, tnr)
plt.xlabel('specifity')
plt.ylabel('sensibility')
plt.plot([0,1], ls = "--", c='red') #red dotted line
plt.plot([0,0], [1,0], ls= '--', c='green'), plt.plot([1,1], ls= '--', c='green') #green dotted line
plt.show()
